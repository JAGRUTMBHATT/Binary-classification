# %% [markdown]
# #Augumentation
#
# to make more image from less like rotete add noice flip ...etc

# %% [markdown]
# ##pre_requization

# %% [markdown]
# install drive  to connect drive

# %%
# !pip install PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# https://drive.google.com/open?id=1UAabraVVn8t8fni0gbDgzwQWItaeK56M

# %% [markdown]
# taking authentication to access google account

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# download raw images (raw data)

# %%
# here we need to enter id of file from shareable link 
download = drive.CreateFile({'id': '13GxTjj_8wMokzGGWVvYg6BKg_snHn8KK'})
download.GetContentFile('images.zip') # here we need to enter the file name that we want to download from google drive
# !unzip images.zip  -d images

# %%
# !ls
# Out:
# adc.json  coats.zip  images.zip  sample_data

# %% [markdown]
# download code to augumentation

# %%
# !git clone https://github.com/tomahim/py-image-dataset-generator.git
# Out:
# Cloning into 'py-image-dataset-generator'...
# remote: Enumerating objects: 330, done.
# remote: Total 330 (delta 0), reused 0 (delta 0), pack-reused 330
# Receiving objects: 100% (330/330), 60.00 KiB | 2.50 MiB/s, done.
# Resolving deltas: 100% (201/201), done.

# %%
# !ls
# Out:
# adc.json   images      py-image-dataset-generator
# coats.zip  images.zip  sample_data

# %%
# %cd py-image-dataset-generator/
# Out:
# /content/py-image-dataset-generator

# %%
# !ls
# Out:
# augmentation		download.py    LICENSE		 tests
# augmentation_config.py	image_grabber  README.md	 utils
# augmentation.py		__init__.py    requirements.txt

# %% [markdown]
# ##start augumentation

# %%
# !python augmentation.py -folder=images/images/coats1 -limit=1000
# Out:
# Progress: [##################################################] 100.0%
#
#  1000 images generated in the folder images/images/coats1/output in 135.87 sec

# %% [markdown]
# ##save to drive

# %% [markdown]
# make zip file

# %%
# !zip -r example.zip  images/images/coats1//output
# Out:
#   adding: images/images/coats1//output/ (stored 0%)
#   adding: images/images/coats1//output/aug_13.jpg (deflated 1%)
#   adding: images/images/coats1//output/aug_583.jpg (deflated 1%)
#   adding: images/images/coats1//output/aug_897.jpg (deflated 1%)
#   adding: images/images/coats1//output/aug_1260.jpg (deflated 1%)
#   adding: images/images/coats1//output/aug_777.jpg (deflated 2%)
#   adding: images/images/coats1//output/aug_443.jpg (deflated 2%)
#   adding: images/images/coats1//output/aug_2074.jpg (deflated 2%)
#   adding: images/images/coats1//output/aug_1061.jpg (deflated 1%)
#   adding: images/images/coats1//output/aug_379.jpg (deflated 2%)
#   adding: images/images/coats1//output/aug_16.jpg (deflated 1%)
#   adding: images/images/coats1//output/aug_1615.jpg (deflated 3%)
#   adding: images/images/coats1//output/aug_2050.jpg (deflated 1%)
#   adding: images/images/coats1//output/aug_840.jpg (deflated 2%)
#   adding: images/images/coats1//output/aug_290.jpg (deflated 3%)
# ...

# %%
# !ls
# Out:
# augmentation		download.py    images	    __pycache__       tests
# augmentation_config.py	example.zip    __init__.py  README.md	      utils
# augmentation.py		image_grabber  LICENSE	    requirements.txt

# %% [markdown]
# again install driver for drive

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# creat and uplode a file to drive

# %%
# Create & upload a file.
uploaded = drive.CreateFile({'title': 'nnnnnn.zip'})
uploaded.SetContentFile('example.zip')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1L6dN1uORUazIjNYYQEB6ugWmxbnyj_jR
